# %%
import pandas as pd
import statsmodels.formula.api as sm
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression
# %matplotlib inline


df = pd.read_csv(r'C:\Users\User1\Desktop\Data Analyst _Projects\Movie_Project\movies.csv')

# %%
df.head(10)
# Out:
#        budget                                  company country  \
# 0   8000000.0            Columbia Pictures Corporation     USA
# 1   6000000.0                       Paramount Pictures     USA
# 2  15000000.0                       Paramount Pictures     USA
# 3  18500000.0   Twentieth Century Fox Film Corporation     USA
# 4   9000000.0                     Walt Disney Pictures     USA
# 5   6000000.0                                  Hemdale      UK
# 6  25000000.0                   Henson Associates (HA)      UK
# 7   6000000.0  De Laurentiis Entertainment Group (DEG)     USA
# 8   9000000.0                       Paramount Pictures     USA
# 9  15000000.0                     SLM Production Group     USA
#
#            director      genre        gross                      name rating  \
# 0        Rob Reiner  Adventure   52287414.0               Stand by Me      R
# 1       John Hughes     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13
# ...

# %%
# checking for missing values

df.isnull().sum()
# Out:
# budget      0
# company     0
# country     0
# director    0
# genre       0
# gross       0
# name        0
# rating      0
# released    0
# runtime     0
# score       0
# star        0
# votes       0
# writer      0
# year        0
# dtype: int64

# %%
# data types

df.dtypes
# Out:
# budget      float64
# company      object
# country      object
# director     object
# genre        object
# gross       float64
# name         object
# rating       object
# released     object
# runtime       int64
# score       float64
# star         object
# votes         int64
# writer       object
# year          int64
# dtype: object

# %%
# Changing data types, from float to int

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df.head(10)
# Out:
#      budget                                  company country  \
# 0   8000000            Columbia Pictures Corporation     USA
# 1   6000000                       Paramount Pictures     USA
# 2  15000000                       Paramount Pictures     USA
# 3  18500000   Twentieth Century Fox Film Corporation     USA
# 4   9000000                     Walt Disney Pictures     USA
# 5   6000000                                  Hemdale      UK
# 6  25000000                   Henson Associates (HA)      UK
# 7   6000000  De Laurentiis Entertainment Group (DEG)     USA
# 8   9000000                       Paramount Pictures     USA
# 9  15000000                     SLM Production Group     USA
#
#            director      genre      gross                      name rating  \
# 0        Rob Reiner  Adventure   52287414               Stand by Me      R
# 1       John Hughes     Comedy   70136369  Ferris Bueller's Day Off  PG-13
# ...

# %%
# Creating a new column that has the same year as the that on the released date

df['releasedyear'] =df['released'].astype(str).str[:4]
df.head(10)
# Out:
#      budget                                  company country  \
# 0   8000000            Columbia Pictures Corporation     USA
# 1   6000000                       Paramount Pictures     USA
# 2  15000000                       Paramount Pictures     USA
# 3  18500000   Twentieth Century Fox Film Corporation     USA
# 4   9000000                     Walt Disney Pictures     USA
# 5   6000000                                  Hemdale      UK
# 6  25000000                   Henson Associates (HA)      UK
# 7   6000000  De Laurentiis Entertainment Group (DEG)     USA
# 8   9000000                       Paramount Pictures     USA
# 9  15000000                     SLM Production Group     USA
#
#            director      genre      gross                      name rating  \
# 0        Rob Reiner  Adventure   52287414               Stand by Me      R
# 1       John Hughes     Comedy   70136369  Ferris Bueller's Day Off  PG-13
# ...

# %%
# Sorting the data in descending order

df.sort_values(by=['gross'], inplace=False, ascending=False)
df.head(10)
# Out:
#      budget                                  company country  \
# 0   8000000            Columbia Pictures Corporation     USA
# 1   6000000                       Paramount Pictures     USA
# 2  15000000                       Paramount Pictures     USA
# 3  18500000   Twentieth Century Fox Film Corporation     USA
# 4   9000000                     Walt Disney Pictures     USA
# 5   6000000                                  Hemdale      UK
# 6  25000000                   Henson Associates (HA)      UK
# 7   6000000  De Laurentiis Entertainment Group (DEG)     USA
# 8   9000000                       Paramount Pictures     USA
# 9  15000000                     SLM Production Group     USA
#
#            director      genre      gross                      name rating  \
# 0        Rob Reiner  Adventure   52287414               Stand by Me      R
# 1       John Hughes     Comedy   70136369  Ferris Bueller's Day Off  PG-13
# ...

# %%
# Pulling all the data

pd.set_option('display.max_rows', None)

# %%
# Dropping duplicate (You have no dropped yet)
df.drop_duplicates()
df.head(10)
# Out:
#      budget                                  company country  \
# 0   8000000            Columbia Pictures Corporation     USA
# 1   6000000                       Paramount Pictures     USA
# 2  15000000                       Paramount Pictures     USA
# 3  18500000   Twentieth Century Fox Film Corporation     USA
# 4   9000000                     Walt Disney Pictures     USA
# 5   6000000                                  Hemdale      UK
# 6  25000000                   Henson Associates (HA)      UK
# 7   6000000  De Laurentiis Entertainment Group (DEG)     USA
# 8   9000000                       Paramount Pictures     USA
# 9  15000000                     SLM Production Group     USA
#
#            director      genre      gross                      name rating  \
# 0        Rob Reiner  Adventure   52287414               Stand by Me      R
# 1       John Hughes     Comedy   70136369  Ferris Bueller's Day Off  PG-13
# ...

# %%
# Checking the relationship between budget and gross, using the scatter plot

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross')
plt.xlabel('Budget')
plt.ylabel('Gross')
plt.show()

# From the graph we can see the positive correlation, hence a positive 
# relationship between Budget and gross.

# %%
# Line of best fit

sns.regplot(x='budget', y='gross', data=df, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Correlation matrix
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.title('Correlation Taubular')
plt.show()

# As we can see below that the correlation between budget and gross is positively HIGH

# %%
correlation_matr = df.corr()
corr_pairs = correlation_matr.unstack()
corr_pairs
# Out:
# budget   budget     1.000000
#          gross      0.712196
#          runtime    0.268226
#          score      0.042145
#          votes      0.503924
#          year       0.291009
# gross    budget     0.712196
#          gross      1.000000
#          runtime    0.224579
#          score      0.165693
#          votes      0.662457
#          year       0.191548
# runtime  budget     0.268226
#          gross      0.224579
#          runtime    1.000000
#          score      0.395343
#          votes      0.317399
#          year       0.087639
# score    budget     0.042145
#          gross      0.165693
#          runtime    0.395343
#          score      1.000000
#          votes      0.393607
#          year       0.105276
# votes    budget     0.503924
#          gross      0.662457
#          runtime    0.317399
#          score      0.393607
#          votes      1.000000
#          year       0.229304
# year     budget     0.291009
#          gross      0.191548
# ...

# %%
# performing regression between budget and gross.
est = sm.ols(formula='budget ~ gross ', data=df).fit()
print(est.params)
print(est.summary())
# Out:
# Intercept    9.404442e+06
# gross        4.530648e-01
# dtype: float64
#                             OLS Regression Results
# ...
# Dep. Variable:                 budget   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.507
# Method:                 Least Squares   F-statistic:                     7018.
# Date:                Fri, 27 Aug 2021   Prob (F-statistic):               0.00
# Time:                        16:50:42   Log-Likelihood:            -1.2612e+05
# No. Observations:                6820   AIC:                         2.522e+05
# Df Residuals:                    6818   BIC:                         2.522e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# Examine the summary statistics
df.describe().T
# Out:
#           count          mean           std     min         25%         50%  \
# budget   6820.0  2.458113e+07  3.702254e+07     0.0        0.00  11000000.0
# gross    6820.0  3.349783e+07  5.819760e+07    70.0  1515839.00  12135679.0
# runtime  6820.0  1.065513e+02  1.802818e+01    50.0       95.00       102.0
# score    6820.0  6.374897e+00  1.003142e+00     1.5        5.80         6.4
# votes    6820.0  7.121952e+04  1.305176e+05    27.0     7665.25     25892.5
# year     6820.0  2.001000e+03  8.944501e+00  1986.0     1993.00      2001.0
#
#                  75%          max
# budget   32000000.00  300000000.0
# gross    40065340.50  936662225.0
# runtime       115.00        366.0
# score           7.10          9.3
# votes       75812.25    1861666.0
# year         2009.00       2016.0

# %%
# histogram
df.hist(bins=50, figsize=(20, 15))
plt.show()
